# %% [markdown]
# # Visualization and Dimensionality Reduction
#
# The goal of this tutorial is to introduce you to different techniques to visualize high dimensional data, namely with PCA, Auto-Encoders and t-SNE. These techniques can also be used to represent high dimeinsinal data in a lower feature space.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
from sklearn.datasets import make_classification

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# First of all we create a small data set with two different classes and 20 different features:

# %%
X, y = make_classification(n_samples=1000, n_features=20,
                    n_informative=5, n_redundant=10,
                    random_state=42)

# scale data between 0 and 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

print(X.shape)
print(y.shape)
# Out:
# (1000, 20)
# (1000,)

# %% [markdown]
# ## PCA
#
# <b>Excercise 1</b>:
# Implement a function that perfomes a PCA on a matrix $X$ and returns a new matriix $X_{reduced}$ that contains only $numDims$ feature with the highest variance.

# %%
def pca(X,numDims):
    # YOUR CODE GOES HERE

# %% [markdown]
# Now, have at look at the result:

# %%
X_reduced = pca(X,2)
plt.scatter(X_reduced[:,0],X_reduced[:,1],c=(y), cmap=plt.cm.get_cmap("jet", 2))
plt.colorbar(ticks=range(2))

# %% [markdown]
# <b>Excercise 2</b>:
# Find k, the number of components in order to retain at least 99% of the variance.

# %%
# YOUR CODE GOES HERE
print('Optimal k to retain 99% variance is:' + str(k))

# %% [markdown]
# ## Auto-encoders
#
# <b>Excercise 3:</b>
# Implement an autoencoder using neural nets (see neural network tutorial) and represent the data with only 2 features and store the result in the variable $X_{neural}$.

# %%
from keras.models import Sequential, Model, Input
from keras.layers.core import Dense, Dropout
encoding_dim = 2

# YOUR CODE GOES HERE
X_neural = np.zeros([X.shape[0],2])

print(X_neural.shape)

# %% [markdown]
# Now, have at look at the result:

# %%
plt.scatter(X_neural[:,0],X_neural[:,1],c=(y), cmap=plt.cm.get_cmap("jet", 2))
plt.colorbar(ticks=range(2))

# %% [markdown]
# ## t-SNE

# %% [markdown]
# <b> Excercise 4:</b>
# Transform the data using the t-SNE algorithm from sklearn. The resulting matrix $X_{tsne}$ should contain only 2 features.

# %%
from sklearn.manifold import TSNE
X_tsne = TSNE().fit_transform(X)

# %% [markdown]
# Now, have at look at the result:

# %%
plt.scatter(X_tsne[:,0],X_tsne[:,1],c=(y), cmap=plt.cm.get_cmap("jet", 2))
plt.colorbar(ticks=range(2))

# %% [markdown]
# <b> Excercise 5:</b>
# Train linear models using the data created with the help of PCA,t-SNE, and the autoencoder. Use a train test split to compare the models with each other. Compare the models in terms of test accuracy and the area under the ROC curve.

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.metrics import auc, roc_curve

# YOUR CODE GOES HERE
